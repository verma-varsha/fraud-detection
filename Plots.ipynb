# %%
import pandas as pd
import numpy as np
import random as rnd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# %%
# from matplotlib import rcParams
# #colorbrewer2 Dark2 qualitative color table
# dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
#                 (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
#                 (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
#                 (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
#                 (0.4, 0.6509803921568628, 0.11764705882352941),
#                 (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
#                 (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

# rcParams['figure.figsize'] = (8, 3)
# rcParams['figure.dpi'] = 150
# # rcParams['axes.color_cycle'] = dark2_colors
# rcParams['lines.linewidth'] = 2
# rcParams['font.size'] = 14
# rcParams['patch.edgecolor'] = 'white'
# rcParams['patch.facecolor'] = dark2_colors[0]
# rcParams['font.family'] = 'StixGeneral'
# rcParams['axes.grid'] = True
# rcParams['axes.facecolor'] = '#eeeeee'

# %%
data_df = pd.read_csv('Dataset.csv', encoding='utf-8')

# %%
# hline=1-data_df[data_df["FraudFound_P"]==1].shape[0]/data_df.shape[0]

# %%
# def stacked_plot(X, Y="FraudFound_P", a=8, b=3, rows=1, columns=2):
#     rcParams['figure.figsize'] = (a, b)
#     fig, (ax1, ax2) = plt.subplots(rows,columns)
#     var = data_df.groupby([X, Y]).XX.sum()
#     b=var.unstack().plot(kind='bar',stacked=True,ax=ax1)
# #     print(var.unstack())
#     b.set_title(X+" (Bar Chart)",weight="bold").set_fontsize('12')
#     var2 = pd.crosstab(data_df[X], data_df[Y]).apply(lambda r: r/r.sum(), axis=1)
#     k=var2.plot(kind='bar', stacked=True, ax=ax2, )
#     k.axhline(hline, color="k")
#     k.set_title(X+" (Stacked Chart)",weight="bold").set_fontsize('12')
# #     Columns.remove(X)

# %%
# stacked_plot("Sex", "FraudFound_P")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-12374d6e02c7> in <module>
# ----> 1 stacked_plot("Sex", "FraudFound_P")
#
# <ipython-input-5-1ea1a5641458> in stacked_plot(X, Y, a, b, rows, columns)
#       2     rcParams['figure.figsize'] = (a, b)
#       3     fig, (ax1, ax2) = plt.subplots(rows,columns)
# ----> 4     var = data_df.groupby([X, Y]).XX.sum()
#       5     b=var.unstack().plot(kind='bar',stacked=True,ax=ax1)
#       6 #     print(var.unstack())
#
# ~/Documents/exl/exl_env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
# --> 536                              (type(self).__name__, attr))
#     537
#     538     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'XX'

# %%
# # import matplotlib.pyplot as plt

# # A = [5., 30., 45., 22.]
# # B = [5., 25., 50., 20.]

# # X = range(4)

# plt.bar(data_df, A, color = 'b')
# plt.bar(X, B, color = 'r', bottom = A)
# plt.show()

# %%
sns.set(style="whitegrid")
# tips = sns.load_dataset("tips")
# ax = sns.barplot(x="Sex", y="FraudFound_P", data=data_df)
ax = sns.countplot(x="Sex", hue="FraudFound_P", data=data_df)

# %%
ax = sns.countplot(x="Year", hue="FraudFound_P", data=data_df)

# %%
ax = sns.countplot(x="AgeOfPolicyHolder", hue="FraudFound_P", data=data_df)

# %%
ax = sns.countplot(x="VehiclePrice", hue="FraudFound_P", data=data_df)

# %%
ax = sns.countplot(x="WitnessPresent", hue="FraudFound_P", data=data_df)
